# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,30,step=3)
y = np.arange(0,5,step =0.5)

plt.plot(y,x,)
plt.plot(y,[0.2,4.5,6,10,11.3,16,20,21.7,23.1,27],'bo')
plt.xlabel("Time (seconds)")
plt.ylabel("x-centriod in meters")
plt.show()
