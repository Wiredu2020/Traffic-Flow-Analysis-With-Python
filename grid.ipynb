# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path =r"C:\Users\JAH\Pictures\Screenshots"
images=[]
x=np.array([1, 2, 3, 4, 5])
img1 = cv2.imread(path+"\ch3_figa.png")
img4 = cv2.imread(path+"\ch3_figa1.png")
img2 =cv2.imread(path+"\ch3_figb.png")
img5 =cv2.imread(path+"\ch3_figb2.png")
img3 =cv2.imread(path+"\ch3_figc.png")
img6 =cv2.imread(path+"\ch3_figc3.png")
images=[img1,img2,img3,img4,img5,img6]
plt.figure(figsize=(20,20))

for i in range(6):
    plt.subplot(3,3,i+1)
    
    
    plt.imshow(images[i],interpolation=None,extent=([0, 70,0,60]))
    plt.xticks(np.arange(0,70,step=10),[0,4.5,9.04,13.57,18.01,22.53,27.1])
    if i<3:
        if i==0:
            plt.title('(a)  Date: 04-Mar-2020 Time:06-23-16')
        if i==1:
            plt.title('(b)  Date: 04-Mar-2020 Time:06-23-18')
        if i==2:
            plt.title('(c)  Date: 04-Mar-2020 Time:06-23-20')
    plt.yticks([])
    if i>2:
        plt.xlabel('Distance in metres')
plt.subplots_adjust(hspace=0.3, wspace=0.05)


#plt.show()

# %%
.subplots_adjust(hspace=0.3, wspace=0.05)

# %%
methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', \
           'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']

grid = np.random.rand(4,4)

fig, ax = plt.subplots(3,6,figsize=(12,6), subplot_kw={'xticks': [0,5,10,15,18,18,45], 'yticks': []})
fig.subplots_adjust(hspace=0.3, wspace=0.05)

ax = ax.ravel()

for n, interp in enumerate(methods):
    ax[n].imshow(grid, interpolation=interp)
    ax[n].set_title(interp)
